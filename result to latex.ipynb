# %%
import pandas as pd
import os
import numpy as np

# %%
latex = """\\begin{center}
\\begin{table}[H]
\\begin{tabular}{|c|c|c|c|c|}
\hline
Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\\\
\hline
# %s\hline
\end{tabular}
\caption{%s}
\end{table}
\end{center}"""

def get_result(file_path, map_no, caption='', is_new=False):
    a_star_results = [
        'AStar Planner & 24.57 & 525.67 & 0.0 & 0.0 \\\\\n',
        'AStar Planner & 13.49 & 568.10 & 0.0 & 0.0 \\\\\n',
        'AStar Planner & 6.42 & 494.97 & 0.0 & 0.0 \\\\\n',
        'AStar Planner & 293.00 & 1715.03 & 0.0 & 0.0 \\\\\n',
        'AStar Planner & 2559.17 & 2206.76 & 0.0 & 0.0 \\\\\n'
    ]
    data = pd.read_csv(file_path)
    
    rows = a_star_results[map_no] if is_new else ''
    for i in range(len(data)):
        rows += " & ".join([str(round(x, 2)) if type(x) == np.float64 else x for x in data.iloc[i]]) + """ \\\\\n"""
    
    return latex % (rows, caption)

# %%
img_template = """\\begin{figure}[H]
\centering
\includegraphics[width=12cm, height=10cm]{%s.png}
\caption{%s}
\end{figure}"""
print(img_template)
# Out:
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{%s.png}
# \caption{%s}
# \end{figure}

# %%
testing_no = 9
for i in range(5):
    file_names = [
        'custom_map_2_params.csv',
        'custom_map_4_params.csv',
        'custom_map_3_params.csv',
        'custom_map_1_params.csv',
        'map_012_params.csv'
    ]
    print("\\section{Map %d}" % (i+1))
    old_file_path = os.path.join('results', 'old_results', 'map %d.csv'%(i+1))
    data = get_result(old_file_path, i, 'Results without Q Learning for map %d' % (i+1))
    print(data)
    print("")
    new_file_path = os.path.join('results', 'testing_%d'%testing_no, file_names[i])
    data = get_result(new_file_path, i, 'Results with Q Learning for map %d' % (i+1), True)
    print(data)
    print("")
    map_name = "map %d" % (i+1)
    algo_full_name = ["AStar", "ABC", "GWO", "PSO"]
    algo_img_name = ["a star", "abc", "gwo", "pso"]
    for j in range(4):
        img_file_name = algo_img_name[j] + ' ' + map_name
        caption = "Path generated by %s algorithm for map %d" % (algo_full_name[j], i+1)
        img_tag = img_template % (img_file_name, caption)
        print(img_tag)
        print('')
    print("\n")
# Out:
# \section{Map 1}
# \begin{center}
# \begin{table}[H]
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\
# \hline
# AStar Planner & 24.57 & 525.67 & 0.0 & 0.0 \\
# ABC Optimizer & 2.53 & 540.23 & 0.0 & 0.0 \\
# GWO Optimizer & 1.6 & 544.39 & 0.0 & 0.0 \\
# PSO Optimizer & 1.49 & 535.7 & 0.0 & 0.0 \\
# \hline
# \end{tabular}
# \caption{Results without Q Learning for map 1}
# \end{table}
# \end{center}
#
# \begin{center}
# \begin{table}[H]
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\
# \hline
# AStar Planner & 24.57 & 525.67 & 0.0 & 0.0 \\
# ABC Optimizer & 0.71 & 620.43 & 0.0 & 0.0 \\
# GWO Optimizer & 0.44 & 616.47 & 0.0 & 0.0 \\
# PSO Optimizer & 0.42 & 603.74 & 0.0 & 0.0 \\
# \hline
# \end{tabular}
# \caption{Results with Q Learning for map 1}
# \end{table}
# \end{center}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{a star map 1.png}
# \caption{Path generated by AStar algorithm for map 1}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{abc map 1.png}
# \caption{Path generated by ABC algorithm for map 1}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{gwo map 1.png}
# \caption{Path generated by GWO algorithm for map 1}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{pso map 1.png}
# \caption{Path generated by PSO algorithm for map 1}
# \end{figure}
#
#
#
# \section{Map 2}
# \begin{center}
# \begin{table}[H]
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\
# \hline
# AStar Planner & 13.49 & 568.1 & 0.0 & 0.0 \\
# ABC Optimizer & 3.22 & 338.73 & 1.0 & 105.6 \\
# GWO Optimizer & 1.35 & 280.34 & 1.0 & 101.2 \\
# PSO Optimizer & 1.33 & 235.95 & 1.0 & 101.0 \\
# \hline
# \end{tabular}
# \caption{Results without Q Learning for map 2}
# \end{table}
# \end{center}
#
# \begin{center}
# \begin{table}[H]
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\
# \hline
# AStar Planner & 13.49 & 568.10 & 0.0 & 0.0 \\
# ABC Optimizer & 0.75 & 438.74 & 1.2 & 67.6 \\
# GWO Optimizer & 0.5 & 619.91 & 0.0 & 0.0 \\
# PSO Optimizer & 0.48 & 566.29 & 1.2 & 7.6 \\
# \hline
# \end{tabular}
# \caption{Results with Q Learning for map 2}
# \end{table}
# \end{center}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{a star map 2.png}
# \caption{Path generated by AStar algorithm for map 2}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{abc map 2.png}
# \caption{Path generated by ABC algorithm for map 2}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{gwo map 2.png}
# \caption{Path generated by GWO algorithm for map 2}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{pso map 2.png}
# \caption{Path generated by PSO algorithm for map 2}
# \end{figure}
#
#
#
# \section{Map 3}
# \begin{center}
# \begin{table}[H]
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\
# \hline
# AStar Planner & 6.42 & 494.97 & 0.0 & 0.0 \\
# ABC Optimizer & 3.5 & 552.56 & 1.2 & 54.6 \\
# GWO Optimizer & 1.74 & 501.2 & 1.0 & 78.8 \\
# PSO Optimizer & 1.69 & 503.0 & 0.0 & 0.0 \\
# \hline
# \end{tabular}
# \caption{Results without Q Learning for map 3}
# \end{table}
# \end{center}
#
# \begin{center}
# \begin{table}[H]
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\
# \hline
# AStar Planner & 6.42 & 494.97 & 0.0 & 0.0 \\
# ABC Optimizer & 2.63 & 704.1 & 0.0 & 0.0 \\
# GWO Optimizer & 1.57 & 665.23 & 0.0 & 0.0 \\
# PSO Optimizer & 1.53 & 656.18 & 0.0 & 0.0 \\
# \hline
# \end{tabular}
# \caption{Results with Q Learning for map 3}
# \end{table}
# \end{center}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{a star map 3.png}
# \caption{Path generated by AStar algorithm for map 3}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{abc map 3.png}
# \caption{Path generated by ABC algorithm for map 3}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{gwo map 3.png}
# \caption{Path generated by GWO algorithm for map 3}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{pso map 3.png}
# \caption{Path generated by PSO algorithm for map 3}
# \end{figure}
#
#
#
# \section{Map 4}
# \begin{center}
# \begin{table}[H]
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\
# \hline
# AStar Planner & 293.0 & 1715.03 & 0.0 & 0.0 \\
# ABC Optimizer & 11.27 & 2098.6 & 1.2 & 231.6 \\
# GWO Optimizer & 5.14 & 1893.33 & 1.6 & 145.6 \\
# PSO Optimizer & 5.12 & 1723.18 & 0.2 & 40.4 \\
# \hline
# \end{tabular}
# \caption{Results without Q Learning for map 4}
# \end{table}
# \end{center}
#
# \begin{center}
# \begin{table}[H]
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\
# \hline
# AStar Planner & 293.00 & 1715.03 & 0.0 & 0.0 \\
# ABC Optimizer & 9.03 & 1890.71 & 0.0 & 0.0 \\
# GWO Optimizer & 5.52 & 1812.67 & 0.2 & 17.2 \\
# PSO Optimizer & 5.52 & 1838.38 & 0.0 & 0.0 \\
# \hline
# \end{tabular}
# \caption{Results with Q Learning for map 4}
# \end{table}
# \end{center}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{a star map 4.png}
# \caption{Path generated by AStar algorithm for map 4}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{abc map 4.png}
# \caption{Path generated by ABC algorithm for map 4}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{gwo map 4.png}
# \caption{Path generated by GWO algorithm for map 4}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{pso map 4.png}
# \caption{Path generated by PSO algorithm for map 4}
# \end{figure}
#
#
#
# \section{Map 5}
# \begin{center}
# \begin{table}[H]
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\
# \hline
# AStar Planner & 2559.17 & 2206.76 & 0.0 & 0.0 \\
# ABC Optimizer & 19.57 & 3426.38 & 2.0 & 126.2 \\
# GWO Optimizer & 7.58 & 2853.1 & 1.4 & 133.8 \\
# PSO Optimizer & 8.59 & 2361.72 & 1.4 & 109.4 \\
# \hline
# \end{tabular}
# \caption{Results without Q Learning for map 5}
# \end{table}
# \end{center}
#
# \begin{center}
# \begin{table}[H]
# \begin{tabular}{|c|c|c|c|c|}
# \hline
# Planner name & Avg. time & Avg. distance & Avg. violation & Avg. violation cost \\
# \hline
# AStar Planner & 2559.17 & 2206.76 & 0.0 & 0.0 \\
# ABC Optimizer & 8.76 & 2201.3 & 1.4 & 90.0 \\
# GWO Optimizer & 4.59 & 2195.58 & 1.2 & 82.6 \\
# PSO Optimizer & 4.85 & 2226.97 & 1.8 & 98.0 \\
# \hline
# \end{tabular}
# \caption{Results with Q Learning for map 5}
# \end{table}
# \end{center}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{a star map 5.png}
# \caption{Path generated by AStar algorithm for map 5}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{abc map 5.png}
# \caption{Path generated by ABC algorithm for map 5}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{gwo map 5.png}
# \caption{Path generated by GWO algorithm for map 5}
# \end{figure}
#
# \begin{figure}[H]
# \centering
# \includegraphics[width=12cm, height=10cm]{pso map 5.png}
# \caption{Path generated by PSO algorithm for map 5}
# \end{figure}

# %%
type(data.iloc[0, 1]) is np.float64
# Out:
# True
